# %%
import tensorflow as tf
# Out:
# C:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
from tensorflow.python.client import device_lib 
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2693189125471874854]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from numpy import expand_dims
from sklearn.model_selection import StratifiedKFold
from keras import Sequential
from keras.layers import *
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam

# %%
from google.colab import drive 
drive.mount('./content/')
# Out:
# Mounted at ./content/

# %%
train = pd.read_csv('/content/content/MyDrive/mnist/train.csv')
test = pd.read_csv('/content/content/MyDrive/mnist/test.csv')
sub = pd.read_csv('/content/content/MyDrive/mnist/submission.csv')

# %% [markdown]
# # Data preprocessing & EDA
# - digit: 가려진 숫자, 우리가 찾을 값
# - letter: 숫자를 가리키는 알파벳

# %%
display(train,test,sub)
# Out:
#         id  digit letter  0  1  2  3  4  ...  776  777  778  779  780  781  782  783
# 0        1      5      L  1  1  1  4  3  ...    0    1    2    4    4    4    3    4
# 1        2      0      B  0  4  0  0  4  ...    0    1    4    1    4    2    1    2
# 2        3      4      L  1  1  2  2  1  ...    3    0    2    0    3    0    2    2
# 3        4      9      D  1  2  0  2  0  ...    2    0    1    4    0    0    1    1
# 4        5      6      A  3  0  2  4  0  ...    3    2    1    3    4    3    1    2
# ...    ...    ...    ... .. .. .. .. ..  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2043  2044      6      V  2  4  3  4  2  ...    2    0    0    1    3    1    4    0
# 2044  2045      1      L  3  2  2  1  1  ...    4    2    1    2    3    4    1    1
# 2045  2046      9      A  4  0  4  0  2  ...    1    1    3    4    2    2    0    0
# 2046  2047      0      Z  2  3  3  0  3  ...    1    1    0    4    1    4    3    1
# 2047  2048      5      Z  4  2  2  1  3  ...    4    0    4    3    2    4    3    4
#
# [2048 rows x 787 columns]
#           id letter  0  1  2  3  4  5  ...  776  777  778  779  780  781  782  783
# 0       2049      L  0  4  0  2  4  2  ...    4    2    2    4    3    4    1    4
# 1       2050      C  4  1  4  0  1  1  ...    2    4    2    4    2    2    1    2
# 2       2051      S  0  4  0  1  3  2  ...    2    0    3    2    3    0    1    4
# 3       2052      K  2  1  3  3  3  4  ...    3    2    4    1    0    4    4    4
# 4       2053      W  1  0  1  1  2  2  ...    1    4    0    2    1    2    3    4
# ...      ...    ... .. .. .. .. .. ..  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 20475  22524      P  1  2  1  1  0  0  ...    3    0    3    0    4    3    1    4
# 20476  22525      S  4  1  1  4  0  0  ...    1    0    0    1    3    1    2    0
# 20477  22526      B  4  2  1  3  2  1  ...    3    4    1    0    3    3    1    1
# 20478  22527      K  1  1  2  3  4  0  ...    0    4    3    3    3    4    4    2
# 20479  22528      S  2  1  0  3  0  3  ...    0    1    4    2    0    2    2    0
#
# [20480 rows x 786 columns]
#           id  digit
# 0       2049      0
# 1       2050      0
# 2       2051      0
# 3       2052      0
# 4       2053      0
# ...      ...    ...
# 20475  22524      0
# 20476  22525      0
# 20477  22526      0
# 20478  22527      0
# 20479  22528      0
#
# [20480 rows x 2 columns]

# %%
# check the distribution of 'digit'
train['digit'].value_counts()
# Out:
# 2    233
# 5    225
# 6    212
# 4    207
# 3    205
# 1    202
# 9    197
# 7    194
# 0    191
# 8    182
# Name: digit, dtype: int64

# %%
# drop columns
train2 = train.drop(['id','digit','letter'],1)
test2 = test.drop(['id','letter'],1)

# %%
# convert pandas dataframe to numpy array
train2 = train2.values
test2 = test2.values

# %%
plt.imshow(train2[100].reshape(28,28))

# %%
train2 = train2.reshape(-1,28,28,1)
test2 = test2.reshape(-1,28,28,1)

# %%
# normalization
train2 = train2/255.
test2 = test2/255.

# %%
# image data generator * data augmentation
idg = ImageDataGenerator(height_shift_range = (-1,1), width_shift_range = (-1,1))
idg2 = ImageDataGenerator()

# %%
# show augmented image data
sample_data = train2[100].copy()
sample = expand_dims(sample_data,0)
sample_datagen = ImageDataGenerator(height_shift_range=(-3,3), width_shift_range=(3,-3))
sample_generator = sample_datagen.flow(sample, batch_size=1)

plt.figure(figsize=(16,10))

for i in range(9):
  plt.subplot(3,3,i+1)
  sample_batch = sample_generator.next()
  sample_image = sample_batch[0]
  plt.imshow(sample_image.reshape(28,28))

# %% [markdown]
# # Validation

# %%
# cross validation
skf = StratifiedKFold(n_splits=40, random_state=42, shuffle=True)

# %% [markdown]
# # Modeling

# %%
# %%time
# patience 만큼의 epoch에도 벗어나지 못하면 callback 호출
# verbose
# factor: 학습률을 1/2로 줄인다 patience 만큼의 epoch에도 벗어나지 못하면 callback 호출
reLR = ReduceLROnPlateau(monitor='accuracy',patience=100, verbose=1, factor=0.5)
es = EarlyStopping(patience=160, verbose=1)

val_loss_min = []
result=0
nth = 0

from tqdm import tqdm
for train_idx, valid_idx in tqdm(skf.split(train2,train['digit'])):
  mc = ModelCheckpoint('best_cvision.h5', save_best_only=True, verbose=1)

  x_train = train2[train_idx]
  x_valid = train2[valid_idx]
  y_train = train['digit'][train_idx]
  y_valid = train['digit'][valid_idx]

  train_generator = idg.flow(x_train, y_train, batch_size=8)
  valid_generator = idg2.flow(x_valid, y_valid)
  test_generator = idg2.flow(test2,shuffle=False)

  model = Sequential()
  model.add(Conv2D(16,(3,3), activation='relu', input_shape=(28,28,1),padding='same'))
  model.add(BatchNormalization())
  model.add(Dropout(0.3))

  model.add(Conv2D(32,(3,3),activation='relu',padding='same'))
  model.add(BatchNormalization())
  model.add(Conv2D(32,(5,5),activation='relu',padding='same')) 
  model.add(BatchNormalization())
  model.add(Conv2D(32,(5,5),activation='relu',padding='same'))
  model.add(BatchNormalization())
  model.add(Conv2D(32,(5,5),activation='relu',padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((3,3)))
  model.add(Dropout(0.3))

  model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
  model.add(BatchNormalization())
  model.add(Conv2D(64,(5,5),activation='relu',padding='same')) 
  model.add(BatchNormalization())
  model.add(MaxPooling2D((3,3)))
  model.add(Dropout(0.3))

  model.add(Flatten())

  model.add(Dense(128,activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.3))
  model.add(Dense(64,activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.3))

  model.add(Dense(10, activation='softmax'))

  # model.compile(loss='sparse_categorical_crossentropy',optimizer=Adam(lr=0.002,epsilon=None), metrics=['acc'])
  model.compile(loss='sparse_categorical_crossentropy',optimizer=Adam(lr=0.002,epsilon=None), metrics=['acc'])
  
  # learning_history = model.fit_generator(train_generator, 
  #                                        epochs=2000, 
  #                                        validation_data=valid_generator,
  #                                        callbacks=[es,mc,reLR])

  learning_history = model.fit(train_generator, 
                                         epochs=2000, 
                                         validation_data=valid_generator,
                                         callbacks=[es,mc,reLR])

  # predict
  model.load_weights('best_cvision.h5')
  result += model.predict_generator(test_generator,verbose=True)

  # save val_loss
  hist = pd.DataFrame(learning_history.history)
  val_loss_min.append(hist['val_loss'].min())

  nth += 1
  print(nth, '번째 학습을 완료했습니다.')
# Out:
# 0it [00:00, ?it/s]
# Epoch 1/2000
# 250/250 [==============================] - 35s 18ms/step - loss: 2.8768 - acc: 0.1074 - val_loss: 8.6110 - val_acc: 0.0962
#
# Epoch 00001: val_loss improved from inf to 8.61103, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 2/2000
# 250/250 [==============================] - 3s 13ms/step - loss: 2.1795 - acc: 0.2280 - val_loss: 6.1340 - val_acc: 0.0962
#
# Epoch 00002: val_loss improved from 8.61103 to 6.13396, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 3/2000
# 250/250 [==============================] - 3s 14ms/step - loss: 1.9040 - acc: 0.3379 - val_loss: 2.0730 - val_acc: 0.2500
#
# Epoch 00003: val_loss improved from 6.13396 to 2.07301, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 4/2000
# 250/250 [==============================] - 3s 14ms/step - loss: 1.7174 - acc: 0.3971 - val_loss: 2.4238 - val_acc: 0.1731
#
# Epoch 00004: val_loss did not improve from 2.07301
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 5/2000
# 250/250 [==============================] - 3s 14ms/step - loss: 1.5446 - acc: 0.4679 - val_loss: 1.1196 - val_acc: 0.5769
#
# Epoch 00005: val_loss improved from 2.07301 to 1.11961, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 6/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 1.2683 - acc: 0.5485 - val_loss: 0.9861 - val_acc: 0.6923
#
# Epoch 00006: val_loss improved from 1.11961 to 0.98606, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 7/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 1.2124 - acc: 0.5846 - val_loss: 0.9385 - val_acc: 0.6346
#
# Epoch 00007: val_loss improved from 0.98606 to 0.93846, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 8/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 1.1632 - acc: 0.6236 - val_loss: 0.7608 - val_acc: 0.6923
#
# Epoch 00008: val_loss improved from 0.93846 to 0.76083, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 9/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.9655 - acc: 0.6810 - val_loss: 0.7059 - val_acc: 0.7692
#
# Epoch 00009: val_loss improved from 0.76083 to 0.70594, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 10/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.9357 - acc: 0.6898 - val_loss: 0.5459 - val_acc: 0.7692
#
# Epoch 00010: val_loss improved from 0.70594 to 0.54589, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 11/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.8861 - acc: 0.6952 - val_loss: 0.5436 - val_acc: 0.7885
#
# Epoch 00011: val_loss improved from 0.54589 to 0.54364, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 12/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.8633 - acc: 0.7245 - val_loss: 0.5447 - val_acc: 0.8077
#
# Epoch 00012: val_loss did not improve from 0.54364
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 13/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.7835 - acc: 0.7476 - val_loss: 0.5420 - val_acc: 0.8077
#
# Epoch 00013: val_loss improved from 0.54364 to 0.54204, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 14/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.7521 - acc: 0.7585 - val_loss: 0.5240 - val_acc: 0.7692
#
# Epoch 00014: val_loss improved from 0.54204 to 0.52404, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 15/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.7747 - acc: 0.7393 - val_loss: 0.5261 - val_acc: 0.7308
#
# Epoch 00015: val_loss did not improve from 0.52404
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 16/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.7140 - acc: 0.7704 - val_loss: 0.3460 - val_acc: 0.8077
#
# Epoch 00016: val_loss improved from 0.52404 to 0.34602, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 17/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.6416 - acc: 0.7932 - val_loss: 0.3590 - val_acc: 0.9038
#
# Epoch 00017: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 18/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.6701 - acc: 0.7637 - val_loss: 0.3499 - val_acc: 0.9231
#
# Epoch 00018: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 19/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.7007 - acc: 0.7758 - val_loss: 0.4617 - val_acc: 0.8077
#
# Epoch 00019: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 20/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.6959 - acc: 0.7742 - val_loss: 0.3857 - val_acc: 0.8462
#
# Epoch 00020: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 21/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.6240 - acc: 0.8118 - val_loss: 0.5866 - val_acc: 0.7692
#
# Epoch 00021: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 22/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.6129 - acc: 0.8010 - val_loss: 0.4078 - val_acc: 0.8269
#
# Epoch 00022: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 23/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5535 - acc: 0.8094 - val_loss: 0.4569 - val_acc: 0.8654
#
# Epoch 00023: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 24/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5746 - acc: 0.8169 - val_loss: 0.3808 - val_acc: 0.8654
#
# Epoch 00024: val_loss did not improve from 0.34602
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 25/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.6675 - acc: 0.7886 - val_loss: 0.3293 - val_acc: 0.9038
#
# Epoch 00025: val_loss improved from 0.34602 to 0.32926, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 26/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5218 - acc: 0.8394 - val_loss: 0.3425 - val_acc: 0.8654
#
# Epoch 00026: val_loss did not improve from 0.32926
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 27/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5759 - acc: 0.8188 - val_loss: 0.2497 - val_acc: 0.9423
#
# Epoch 00027: val_loss improved from 0.32926 to 0.24970, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 28/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5803 - acc: 0.8156 - val_loss: 0.2730 - val_acc: 0.9038
#
# Epoch 00028: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 29/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4997 - acc: 0.8424 - val_loss: 0.4283 - val_acc: 0.8846
#
# Epoch 00029: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 30/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5114 - acc: 0.8423 - val_loss: 0.4418 - val_acc: 0.8462
#
# Epoch 00030: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 31/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4862 - acc: 0.8479 - val_loss: 0.3394 - val_acc: 0.8654
#
# Epoch 00031: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 32/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4217 - acc: 0.8638 - val_loss: 0.2652 - val_acc: 0.8846
#
# Epoch 00032: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 33/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5192 - acc: 0.8416 - val_loss: 1.5627 - val_acc: 0.5192
#
# Epoch 00033: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 34/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.6985 - acc: 0.7891 - val_loss: 0.3970 - val_acc: 0.9038
#
# Epoch 00034: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 35/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5003 - acc: 0.8423 - val_loss: 0.2782 - val_acc: 0.8846
#
# Epoch 00035: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 36/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4367 - acc: 0.8618 - val_loss: 0.2600 - val_acc: 0.8846
#
# Epoch 00036: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 37/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4620 - acc: 0.8539 - val_loss: 0.4260 - val_acc: 0.8269
#
# Epoch 00037: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 38/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4688 - acc: 0.8470 - val_loss: 0.3464 - val_acc: 0.9038
#
# Epoch 00038: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 39/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.5047 - acc: 0.8348 - val_loss: 0.3518 - val_acc: 0.8654
#
# Epoch 00039: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 40/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4184 - acc: 0.8677 - val_loss: 0.3203 - val_acc: 0.9231
#
# Epoch 00040: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 41/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3520 - acc: 0.8853 - val_loss: 0.3342 - val_acc: 0.9038
#
# Epoch 00041: val_loss did not improve from 0.24970
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 42/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3871 - acc: 0.8661 - val_loss: 0.2144 - val_acc: 0.9231
#
# Epoch 00042: val_loss improved from 0.24970 to 0.21443, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 43/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3483 - acc: 0.8964 - val_loss: 0.3272 - val_acc: 0.9038
#
# Epoch 00043: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 44/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4590 - acc: 0.8598 - val_loss: 0.3700 - val_acc: 0.8846
#
# Epoch 00044: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 45/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4121 - acc: 0.8711 - val_loss: 0.3554 - val_acc: 0.9038
#
# Epoch 00045: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 46/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3698 - acc: 0.8806 - val_loss: 0.2849 - val_acc: 0.8846
#
# Epoch 00046: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 47/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3833 - acc: 0.8831 - val_loss: 0.3561 - val_acc: 0.9231
#
# Epoch 00047: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 48/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4092 - acc: 0.8754 - val_loss: 0.2402 - val_acc: 0.9038
#
# Epoch 00048: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 49/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3497 - acc: 0.8846 - val_loss: 0.3001 - val_acc: 0.8846
#
# Epoch 00049: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 50/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3503 - acc: 0.8884 - val_loss: 0.2706 - val_acc: 0.9038
#
# Epoch 00050: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 51/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3163 - acc: 0.8999 - val_loss: 0.2390 - val_acc: 0.9038
#
# Epoch 00051: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 52/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3106 - acc: 0.9005 - val_loss: 0.2589 - val_acc: 0.9038
#
# Epoch 00052: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 53/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3612 - acc: 0.8973 - val_loss: 0.2588 - val_acc: 0.8846
#
# Epoch 00053: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 54/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.3757 - acc: 0.8758 - val_loss: 0.2679 - val_acc: 0.8846
#
# Epoch 00054: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 55/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3321 - acc: 0.8926 - val_loss: 0.2324 - val_acc: 0.9231
#
# Epoch 00055: val_loss did not improve from 0.21443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 56/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.4772 - acc: 0.8548 - val_loss: 0.2066 - val_acc: 0.9038
#
# Epoch 00056: val_loss improved from 0.21443 to 0.20665, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 57/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3309 - acc: 0.8860 - val_loss: 0.3234 - val_acc: 0.8846
#
# Epoch 00057: val_loss did not improve from 0.20665
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 58/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3673 - acc: 0.8927 - val_loss: 0.2844 - val_acc: 0.9231
#
# Epoch 00058: val_loss did not improve from 0.20665
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 59/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.3266 - acc: 0.9058 - val_loss: 0.2962 - val_acc: 0.9038
#
# Epoch 00059: val_loss did not improve from 0.20665
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 60/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.2854 - acc: 0.9091 - val_loss: 0.4260 - val_acc: 0.8846
#
# Epoch 00060: val_loss did not improve from 0.20665
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 61/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.2986 - acc: 0.9101 - val_loss: 0.3179 - val_acc: 0.8846
#
# Epoch 00061: val_loss did not improve from 0.20665
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 62/2000
# 250/250 [==============================] - 4s 14ms/step - loss: 0.
val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 119/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1891 - acc: 0.9441 - val_loss: 0.3171 - val_acc: 0.9231
#
# Epoch 00119: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 120/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1698 - acc: 0.9414 - val_loss: 0.3586 - val_acc: 0.9231
#
# Epoch 00120: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 121/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1309 - acc: 0.9623 - val_loss: 0.4470 - val_acc: 0.9038
#
# Epoch 00121: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 122/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1404 - acc: 0.9616 - val_loss: 0.3464 - val_acc: 0.9423
#
# Epoch 00122: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 123/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1578 - acc: 0.9562 - val_loss: 0.4814 - val_acc: 0.9038
#
# Epoch 00123: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 124/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.2134 - acc: 0.9359 - val_loss: 0.2971 - val_acc: 0.9038
#
# Epoch 00124: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 125/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1536 - acc: 0.9577 - val_loss: 0.4068 - val_acc: 0.9038
#
# Epoch 00125: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 126/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1165 - acc: 0.9675 - val_loss: 0.3337 - val_acc: 0.9038
#
# Epoch 00126: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 127/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1342 - acc: 0.9583 - val_loss: 0.5756 - val_acc: 0.8846
#
# Epoch 00127: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 128/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1521 - acc: 0.9564 - val_loss: 0.4842 - val_acc: 0.9038
#
# Epoch 00128: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 129/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1316 - acc: 0.9568 - val_loss: 0.4719 - val_acc: 0.9231
#
# Epoch 00129: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 130/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1440 - acc: 0.9546 - val_loss: 0.5251 - val_acc: 0.8654
#
# Epoch 00130: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 131/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1151 - acc: 0.9611 - val_loss: 0.4044 - val_acc: 0.8846
#
# Epoch 00131: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 132/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1494 - acc: 0.9554 - val_loss: 0.3410 - val_acc: 0.9038
#
# Epoch 00132: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 133/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1247 - acc: 0.9641 - val_loss: 0.3772 - val_acc: 0.8846
#
# Epoch 00133: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 134/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1644 - acc: 0.9454 - val_loss: 0.2670 - val_acc: 0.9423
#
# Epoch 00134: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 135/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1693 - acc: 0.9544 - val_loss: 0.4246 - val_acc: 0.9038
#
# Epoch 00135: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 136/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1526 - acc: 0.9513 - val_loss: 0.4522 - val_acc: 0.9038
#
# Epoch 00136: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 137/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1120 - acc: 0.9662 - val_loss: 0.3964 - val_acc: 0.8654
#
# Epoch 00137: val_loss did not improve from 0.18381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 138/2000
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1320 - acc: 0.9647 - val_loss: 0.3895 - val_acc: 0.9038
#
# Epoch 00138: val_loss did not improve from 0.18381
# ...
#
# Epoch 00378: val_loss did not improve from 0.03245
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 379/2000
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1106 - acc: 0.9645 - val_loss: 0.4328 - val_acc: 0.9038
#
# Epoch 00379: val_loss did not improve from 0.03245
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 380/2000
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0823 - acc: 0.9736 - val_loss: 0.4643 - val_acc: 0.9231
#
# Epoch 00380: val_loss did not improve from 0.03245
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 381/2000
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0676 - acc: 0.9782 - val_loss: 0.3914 - val_acc: 0.9231
#
# Epoch 00381: val_loss did not improve from 0.03245
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 382/2000
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0672 - acc: 0.9814 - val_loss: 0.3644 - val_acc: 0.9231
#
# Epoch 00382: val_loss did not improve from 0.03245
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 00382: early stopping
# 640/640 [==============================] - 5s 7ms/step
# 6it [2:20:13, 1430.02s/it]
# 6 번째 학습을 완료했습니다.
# Epoch 1/2000
# 250/250 [==============================] - 6s 19ms/step - loss: 2.9089 - acc: 0.1325 - val_loss: 5.2334 - val_acc: 0.0962
#
# Epoch 00001: val_loss improved from inf to 5.23342, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 2/2000
# 250/250 [==============================] - 5s 18ms/step - loss: 2.1595 - acc: 0.2363 - val_loss: 3.0732 - val_acc: 0.1538
#
# Epoch 00002: val_loss improved from 5.23342 to 3.07321, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 3/2000
# 250/250 [==============================] - 4s 18ms/step - loss: 1.9137 - acc: 0.3209 - val_loss: 1.9340 - val_acc: 0.3654
#
# Epoch 00003: val_loss improved from 3.07321 to 1.93395, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 4/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 1.7474 - acc: 0.3829 - val_loss: 2.0302 - val_acc: 0.2692
#
# Epoch 00004: val_loss did not improve from 1.93395
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 5/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 1.5402 - acc: 0.4629 - val_loss: 1.6352 - val_acc: 0.4423
#
# Epoch 00005: val_loss improved from 1.93395 to 1.63524, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 6/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 1.2757 - acc: 0.5659 - val_loss: 1.0651 - val_acc: 0.5769
#
# Epoch 00006: val_loss improved from 1.63524 to 1.06509, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 7/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 1.1461 - acc: 0.6135 - val_loss: 0.9154 - val_acc: 0.7500
#
# Epoch 00007: val_loss improved from 1.06509 to 0.91544, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 8/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 1.0562 - acc: 0.6408 - val_loss: 0.7903 - val_acc: 0.7500
#
# Epoch 00008: val_loss improved from 0.91544 to 0.79027, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 9/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 1.0294 - acc: 0.6685 - val_loss: 0.6663 - val_acc: 0.8077
#
# Epoch 00009: val_loss improved from 0.79027 to 0.66635, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 10/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.8664 - acc: 0.7033 - val_loss: 0.7755 - val_acc: 0.7500
#
# Epoch 00010: val_loss did not improve from 0.66635
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 11/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.8100 - acc: 0.7424 - val_loss: 0.7024 - val_acc: 0.8077
#
# Epoch 00011: val_loss did not improve from 0.66635
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 12/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.8494 - acc: 0.7141 - val_loss: 0.7397 - val_acc: 0.7885
#
# Epoch 00012: val_loss did not improve from 0.66635
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 13/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.7620 - acc: 0.7490 - val_loss: 0.6595 - val_acc: 0.7308
#
# Epoch 00013: val_loss improved from 0.66635 to 0.65947, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 14/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.7611 - acc: 0.7496 - val_loss: 1.3696 - val_acc: 0.6346
#
# Epoch 00014: val_loss did not improve from 0.65947
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 15/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.7940 - acc: 0.7343 - val_loss: 0.4621 - val_acc: 0.8846
#
# Epoch 00015: val_loss improved from 0.65947 to 0.46210, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 16/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.7010 - acc: 0.7607 - val_loss: 0.3028 - val_acc: 0.9615
#
# Epoch 00016: val_loss improved from 0.46210 to 0.30283, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 17/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.6061 - acc: 0.8057 - val_loss: 0.4550 - val_acc: 0.8269
#
# Epoch 00017: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 18/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.7276 - acc: 0.7681 - val_loss: 0.3465 - val_acc: 0.9231
#
# Epoch 00018: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 19/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.5937 - acc: 0.8058 - val_loss: 0.6739 - val_acc: 0.8077
#
# Epoch 00019: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 20/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.6518 - acc: 0.7770 - val_loss: 0.3455 - val_acc: 0.9038
#
# Epoch 00020: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 21/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.6890 - acc: 0.7857 - val_loss: 0.3742 - val_acc: 0.8846
#
# Epoch 00021: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 22/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.5243 - acc: 0.8281 - val_loss: 0.4791 - val_acc: 0.7885
#
# Epoch 00022: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 23/2000
# 250/250 [==============================] - 4s 18ms/step - loss: 0.5750 - acc: 0.8222 - val_loss: 0.4280 - val_acc: 0.8654
#
# Epoch 00023: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 24/2000
# 250/250 [==============================] - 4s 18ms/step - loss: 0.6142 - acc: 0.7979 - val_loss: 0.8782 - val_acc: 0.7500
#
# Epoch 00024: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 25/2000
# 250/250 [==============================] - 4s 18ms/step - loss: 0.5954 - acc: 0.8036 - val_loss: 0.3846 - val_acc: 0.8654
#
# Epoch 00025: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 26/2000
# 250/250 [==============================] - 4s 18ms/step - loss: 0.6009 - acc: 0.8135 - val_loss: 0.8558 - val_acc: 0.7308
#
# Epoch 00026: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 27/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.7549 - acc: 0.7409 - val_loss: 0.4533 - val_acc: 0.8077
#
# Epoch 00027: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 28/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.5612 - acc: 0.8235 - val_loss: 0.4675 - val_acc: 0.8846
#
# Epoch 00028: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 29/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.5459 - acc: 0.8363 - val_loss: 0.3601 - val_acc: 0.9038
#
# Epoch 00029: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 30/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4825 - acc: 0.8492 - val_loss: 0.3092 - val_acc: 0.9231
#
# Epoch 00030: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 31/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4823 - acc: 0.8548 - val_loss: 0.3039 - val_acc: 0.8654
#
# Epoch 00031: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 32/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4624 - acc: 0.8547 - val_loss: 0.3171 - val_acc: 0.8654
#
# Epoch 00032: val_loss did not improve from 0.30283
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 33/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4981 - acc: 0.8458 - val_loss: 0.2127 - val_acc: 0.9423
#
# Epoch 00033: val_loss improved from 0.30283 to 0.21270, saving model to best_cvision.h5
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 34/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.5326 - acc: 0.8345 - val_loss: 0.2836 - val_acc: 0.8846
#
# Epoch 00034: val_loss did not improve from 0.21270
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 35/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4630 - acc: 0.8464 - val_loss: 0.2763 - val_acc: 0.9038
#
# Epoch 00035: val_loss did not improve from 0.21270
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 36/2000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4676 - acc: 0.8568 - val_loss: 0.2801 - val_acc: 0.9038
#
# Epoch 00036: val_loss did not improve from 0.21270
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 37/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4658 - acc: 0.8561 - val_loss: 0.3067 - val_acc: 0.8846
#
# Epoch 00037: val_loss did not improve from 0.21270
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 38/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4637 - acc: 0.8571 - val_loss: 0.5551 - val_acc: 0.8654
#
# Epoch 00038: val_loss did not improve from 0.21270
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 39/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4947 - acc: 0.8313 - val_loss: 0.2457 - val_acc: 0.9231
#
# Epoch 00039: val_loss did not improve from 0.21270
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 40/2000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.4451 - acc: 0.8595 - val_loss: 0.3124 - val_acc: 0.8846
#
# Epoch 00040: val_loss did not improve from 0.21270
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# Epoch 41/2000
# 157/250 [=================>............] - ETA: 1s - loss: 0.4554 - acc: 0.8431

# %%
display(val_loss_min, np.mean(val_loss_min))

# %%
model.summary()

# %% [markdown]
# # Submission

# %%
sub['digit']=result.argmax(1)

# %%
sub

# %%
sub.to_csv('result.csv', index=False)
